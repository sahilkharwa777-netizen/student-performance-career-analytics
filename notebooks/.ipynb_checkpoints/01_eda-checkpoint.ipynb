# %%
import pandas as pd

df = pd.read_excel("../data/Power BI Updated Data analyst Data.xlsx")

df.head()
# Out:
#   First Name           Email ID  Quantity                  Events  \
# 0     ANIKET     aniket@xyz.com         1  Art of Resume Building
# 1  Dhanshree  dhanshree@xyz.com         1  Art of Resume Building
# 2     Dhiraj     dhiraj@xyz.com         1  Art of Resume Building
# 3      Pooja      pooja@xyz.com         1  Art of Resume Building
# 4     Aayush     aayush@xyz.com         1  Art of Resume Building
#
#   Attendee Status                                       College Name  \
# 0       Attending  D Y PATIL INSTITUTE OF MCA AND MANAGEMENT AKUR...
# 1       Attending                   AP SHAH INSTITUTE OF TECHNOLOGY
# 2       Attending       Don Bosco College of Engineering Fatorda Goa
# 3       Attending           Pillai College of Engineering New Panvel
# 4       Attending                               St Xavier's College
#
#         How did you come to know about this event?  \
# 0                                            Email
# ...

# %%
df.columns
# Out:
# Index(['First Name', 'Email ID', 'Quantity', 'Events', 'Attendee Status',
#        'College Name', 'How did you come to know about this event?',
#        'Specify in "Others" (how did you come to know about this event)',
#        'Designation', 'Year of Graduation', 'City', 'CGPA',
#        'Experience with python (Months)', 'Family Income',
#        'Expected salary (Lac)', 'Leadership- skills'],
#       dtype='str')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4894 entries, 0 to 4893
# Data columns (total 16 columns):
#  #   Column                                                           Non-Null Count  Dtype
# ---  ------                                                           --------------  -----
#  0   First Name                                                       4894 non-null   str
#  1   Email ID                                                         4894 non-null   str
#  2   Quantity                                                         4894 non-null   int64
#  3   Events                                                           4894 non-null   str
#  4   Attendee Status                                                  4894 non-null   str
#  5   College Name                                                     4879 non-null   str
#  6   How did you come to know about this event?                       2678 non-null   str
# ...

# %%
df.describe()
# Out:
#        Quantity  Year of Graduation         CGPA  \
# count    4894.0         4894.000000  4894.000000
# mean        1.0         2024.176951     8.038476
# std         0.0            1.000180     1.005184
# min         1.0         2023.000000     6.200000
# 25%         1.0         2023.000000     7.200000
# 50%         1.0         2024.000000     7.900000
# 75%         1.0         2025.000000     8.900000
# max         1.0         2026.000000     9.900000
#
#        Experience with python (Months)  Expected salary (Lac)
# count                      4894.000000            4894.000000
# mean                          5.395586              13.935635
# std                           1.705364               6.451959
# min                           3.000000               5.000000
# 25%                           4.000000               8.000000
# 50%                           5.000000              13.000000
# 75%                           7.000000              19.000000
# ...

# %%
df.isnull().sum()
# Out:
# First Name                                                            0
# Email ID                                                              0
# Quantity                                                              0
# Events                                                                0
# Attendee Status                                                       0
# College Name                                                         15
# How did you come to know about this event?                         2216
# Specify in "Others" (how did you come to know about this event)    4805
# Designation                                                           0
# Year of Graduation                                                    0
# City                                                                  0
# CGPA                                                                  0
# Experience with python (Months)                                       0
# ...

# %%
    df.nunique()
# Out:
# First Name                                                         2324
# Email ID                                                           2157
# Quantity                                                              1
# Events                                                               16
# Attendee Status                                                       2
# College Name                                                         55
# How did you come to know about this event?                           99
# Specify in "Others" (how did you come to know about this event)      11
# Designation                                                          49
# Year of Graduation                                                    4
# City                                                                177
# CGPA                                                                 37
# Experience with python (Months)                                       6
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.head(10)
# Out:
#   First Name           Email ID  Quantity                  Events  \
# 0     ANIKET     aniket@xyz.com         1  Art of Resume Building
# 1  Dhanshree  dhanshree@xyz.com         1  Art of Resume Building
# 2     Dhiraj     dhiraj@xyz.com         1  Art of Resume Building
# 3      Pooja      pooja@xyz.com         1  Art of Resume Building
# 4     Aayush     aayush@xyz.com         1  Art of Resume Building
# 5    Mrunali    mrunali@xyz.com         1  Art of Resume Building
# 6      Durga      durga@xyz.com         1  Art of Resume Building
# 7     Ruchit     ruchit@xyz.com         1  Art of Resume Building
# 8   Mayuresh   mayuresh@xyz.com         1  Art of Resume Building
# 9      ROHIT      rohit@xyz.com         1  Art of Resume Building
#
#   Attendee Status                                       College Name  \
# 0       Attending  D Y PATIL INSTITUTE OF MCA AND MANAGEMENT AKUR...
# 1       Attending                   AP SHAH INSTITUTE OF TECHNOLOGY
# ...

# %%
df["Email ID"].nunique()
# Out:
# 2157

# %%
df["CGPA"].mean()
# Out:
# np.float64(8.038475684511647)

# %%
df["Experience with python (Months)"].describe()
# Out:
# count    4894.000000
# mean        5.395586
# std         1.705364
# min         3.000000
# 25%         4.000000
# 50%         5.000000
# 75%         7.000000
# max         8.000000
# Name: Experience with python (Months), dtype: float64

# %% [markdown]
# as data of family income stored as string

# %%
df["Family Income"] = pd.to_numeric(df["Family Income"], errors='coerce')

# %%
df["Family Income"].mean()
# Out:
# nan

# %%
df["Family Income"].isnull().sum()
# Out:
# np.int64(4894)

# %%
df.groupby("College Name")["CGPA"].mean().sort_values(ascending=False).head(5)
# Out:
# College Name
# THAKUR INSTITUTE OF MANAGEMENT STUDIES, CAREER DEVELOPMENT & RESEARCH - [TIMSCDR]    8.585714
# St Xavier's College                                                                  8.578571
# B. K. Birla College of Arts, Science & Commerce (Autonomous), Kalyan                 8.456410
# Symbiosis Institute of Technology, Pune                                              8.303448
# AP SHAH INSTITUTE OF TECHNOLOGY                                                      8.283333
# Name: CGPA, dtype: float64

# %%
df["CGPA"].describe()
# Out:
# count    4894.000000
# mean        8.038476
# std         1.005184
# min         6.200000
# 25%         7.200000
# 50%         7.900000
# 75%         8.900000
# max         9.900000
# Name: CGPA, dtype: float64

# %%
df.groupby("City")["CGPA"].mean().sort_values(ascending=False)
# Out:
# City
# Kolhapur     8.557143
# Raipur       8.507143
# Sonipat      8.464286
# Gurugram     8.459259
# Puri         8.450000
#                ...
# Panipat      7.615385
# Nashik       7.592857
# Daman        7.421429
# Rewari       7.392308
# New Delhi    7.307143
# Name: CGPA, Length: 177, dtype: float64

# %%
df[["CGPA", "Expected salary (Lac)"]].corr()
# Out:
#                            CGPA  Expected salary (Lac)
# CGPA                   1.000000               0.181196
# Expected salary (Lac)  0.181196               1.000000

# %%
df.groupby("Leadership- skills")["CGPA"].mean()
# Out:
# Leadership- skills
# no     8.040444
# no     8.034816
# yes    8.036787
# Name: CGPA, dtype: float64

# %%
import matplotlib.pyplot as plt

df["CGPA"].hist()
plt.title("CGPA Distribution")
plt.xlabel("CGPA")
plt.ylabel("Count")
plt.show()

# %%
df = df.drop_duplicates()
df = df.dropna()
